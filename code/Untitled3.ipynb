# %%
pip install skl2onnx onnx onnxruntime
# Out:
# Collecting skl2onnx
#   Downloading skl2onnx-1.20.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting onnx
#   Downloading onnx-1.22.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.23.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: scikit-learn>=1.1 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from skl2onnx) (1.7.2)
# Requirement already satisfied: numpy>=1.23.2 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from onnx) (2.2.6)
# Requirement already satisfied: protobuf>=4.25.1 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from onnx) (7.35.1)
# Requirement already satisfied: typing_extensions>=4.15.0 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from onnx) (4.15.0)
# Collecting ml_dtypes>=0.5.4 (from onnx)
#   Downloading ml_dtypes-0.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: packaging in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from onnxruntime) (26.2)
# Requirement already satisfied: sympy in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from scikit-learn>=1.1->skl2onnx) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from scikit-learn>=1.1->skl2onnx) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from scikit-learn>=1.1->skl2onnx) (3.6.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fred/miniconda3/envs/Deus/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)
# Downloading skl2onnx-1.20.0-py3-none-any.whl (317 kB)
# Downloading onnx-1.22.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 414.9 kB/s  0:01:06 eta 0:00:010:00:02
# Downloading onnxruntime-1.23.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 469.4 kB/s  0:00:35 eta 0:00:010:00:02
# Downloading ml_dtypes-0.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (412 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Installing collected packages: ml_dtypes, humanfriendly, onnx, coloredlogs, skl2onnx, onnxruntime
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [onnxruntime] 5/6 [onnxruntime]nnx]ndly]
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 ml_dtypes-0.6.0 onnx-1.22.0 onnxruntime-1.23.2 skl2onnx-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
import numpy as np

from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType


# ----------------------------------------
# 1. Cargar modelo de Scikit-Learn
# ----------------------------------------

with open("asl_model.p", "rb") as f:
    model_dict = pickle.load(f)

model = model_dict["model"]


# ----------------------------------------
# 2. Definir entrada
# ----------------------------------------

initial_type = [
    ("float_input", FloatTensorType([None, 42]))
]


# ----------------------------------------
# 3. Convertir Random Forest -> ONNX
# ----------------------------------------

onnx_model = convert_sklearn(
    model,
    initial_types=initial_type,
    target_opset=18
)


# ----------------------------------------
# 4. Guardar
# ----------------------------------------

with open("asl_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())


print("Modelo convertido correctamente.")
